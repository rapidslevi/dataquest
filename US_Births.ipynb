# %%
csv_list = open("US_births_1994-2003_CDC_NCHS.csv").read().split("\n")
# Out:
# ['year,month,date_of_month,day_of_week,births', '1994,1,1,6,8096', '1994,1,2,7,7772', '1994,1,3,1,10142', '1994,1,4,2,11248', '1994,1,5,3,11053', '1994,1,6,4,11406', '1994,1,7,5,11251', '1994,1,8,6,8653', '1994,1,9,7,7910']

# %%
csv_list[0:10]
# Out:
# ['year,month,date_of_month,day_of_week,births',
#  '1994,1,1,6,8096',
#  '1994,1,2,7,7772',
#  '1994,1,3,1,10142',
#  '1994,1,4,2,11248',
#  '1994,1,5,3,11053',
#  '1994,1,6,4,11406',
#  '1994,1,7,5,11251',
#  '1994,1,8,6,8653',
#  '1994,1,9,7,7910']

# %%
def read_csv(births):
    string_data = open(births).read()
    string_list = string_data.split("\n")[1:]
    final_list = []
    for birth in string_list:
        string_fields = birth.split(",")
        int_fields = []
        for value in string_fields:
            int_fields.append(int(value))
        final_list.append(int_fields)
    return final_list
cdc_list = read_csv("US_births_1994-2003_CDC_NCHS.csv")

# %%
cdc_list[0:10]
# Out:
# [[1994, 1, 1, 6, 8096],
#  [1994, 1, 2, 7, 7772],
#  [1994, 1, 3, 1, 10142],
#  [1994, 1, 4, 2, 11248],
#  [1994, 1, 5, 3, 11053],
#  [1994, 1, 6, 4, 11406],
#  [1994, 1, 7, 5, 11251],
#  [1994, 1, 8, 6, 8653],
#  [1994, 1, 9, 7, 7910],
#  [1994, 1, 10, 1, 10498]]

# %%
def month_births(data):
    births_per_month = {}
    for row in data:
        month = row[1]
        births = row[4]
        if month in births_per_month:
            births_per_month[month] = births_per_month[month] + births
        else:
            births_per_month[month] = births
    return(births_per_month)
cdc_month_births = month_births(cdc_list)

# %%
cdc_month_births
# Out:
# {1: 3232517,
#  2: 3018140,
#  3: 3322069,
#  4: 3185314,
#  5: 3350907,
#  6: 3296530,
#  7: 3498783,
#  8: 3525858,
#  9: 3439698,
#  10: 3378814,
#  11: 3171647,
#  12: 3301860}

# %%
def dow_births(data):
    births_per_dow = {}
    
    for row in data:
        dow = row[3]
        births = row[4]
        if dow in births_per_dow:
            births_per_dow[dow] = births_per_dow[dow] + births
        else:
            births_per_dow[dow] = births
    return births_per_dow
    
cdc_dow_births = dow_births(cdc_list)

# %%
cdc_dow_births
# Out:
# {1: 5789166,
#  2: 6446196,
#  3: 6322855,
#  4: 6288429,
#  5: 6233657,
#  6: 4562111,
#  7: 4079723}

# %%
def calc_counts(data, column):
    sums_dict = {}
    for row in data:
        col_value = row[column]
        births = row[4]
        if col_value in sums_dict:
            sums_dict[col_value] = sums_dict[col_value] + births
        else:
            sums_dict[col_value] = births
    return sums_dict
cdc_year_births = calc_counts(cdc_list[0])
cdc_month_births = calc_counts(cdc_list[1])
cdc_dom_births = calc_counts(cdc_list[2])
cdc_dow_births = calc_counts(cdc_list[3])
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-28-f2cc299d98f5> in <module>()
#       9             sums_dict[col_value] = births
#      10     return sums_dict
# ---> 11 cdc_year_births = calc_counts(cdc_list[0])
#      12 cdc_month_births = calc_counts(cdc_list[1])
#      13 cdc_dom_births = calc_counts(cdc_list[2])
#
# TypeError: calc_counts() missing 1 required positional argument: 'column'
